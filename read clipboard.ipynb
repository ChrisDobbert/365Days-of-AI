# %%
import pyforest
import bamboolib as bam
import missingno as msno
#import mglearn
from inspect import getmembers, isfunction

# %%
import pandas as pd
df = pd.read_clipboard()

# %%
df
# Out:
#            product_title                       product_subtitle  gender  \
# 692      Sertig Headband                              Stirnband  unisex
# 208   Mammut Neck Gaiter                     Multifunktionstuch  unisex
# 525      Sertig Headband                              Stirnband  unisex
# 178      Sertig Headband                              Stirnband  unisex
# 886      Sertig Headband                              Stirnband  unisex
# ..                   ...                                    ...     ...
# 283          3850 Jacket  Hardshell-Jacke mit Kapuze für Herren     men
# 748  Nordwand Pro Hooded   Hardshell-Jacke mit Kapuze für Damen   women
# 757  Nordwand Pro Hooded   Hardshell-Jacke mit Kapuze für Damen   women
# 246  Nordwand Pro Hooded  Hardshell-Jacke mit Kapuze für Herren     men
# 240              Photics  Hardshell-Jacke mit Kapuze für Herren     men
#
#      product_price  product_price_old sale_type  \
# 692           25.0                  0       NEU
# 208           25.0                  0       NEU
# 525           25.0                  0       NaN
# 178           25.0                  0       NEU
# 886           25.0                  0       NaN
# ..             ...                ...       ...
# 283          850.0                  0       NaN
# 748          899.0                  0       NaN
# 757          899.0                  0       NaN
# 246          899.0                  0       NaN
# 240          999.0                  0       NaN
#
#                                    product_description
# 692  Praktisch für dein anspruchsvolles Training in...
# 208  MAMMUT Neck Gaiter - praktisches Accessoire in...
# 525  Praktisch für dein anspruchsvolles Training in...
# 178  Praktisch für dein anspruchsvolles Training in...
# 886  Praktisch für dein anspruchsvolles Training in...
# ..                                                 ...
# 283  Für deinen urbanen Look: Die 3850 HS Hooded Ja...
# 748  Schützt mich bei allen Wetterbedingungen und w...
# 757  Schützt mich bei allen Wetterbedingungen und w...
# 246  Eiger, Matterhorn, Grand Jorasses – diese Name...
# 240  Photics HS Thermo Hooded Jacket Men. Die weltw...
#
# [1022 rows x 7 columns]
